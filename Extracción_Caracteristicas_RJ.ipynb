# %%
#importar librerias 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
from funpymodeling.exploratory import freq_tbl

# %%
rio = pd.read_csv("Rio de Janeiro sin atipicos.csv")

# %%
rio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36967 entries, 0 to 36966
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   last_scraped                 36967 non-null  object
#  1   name                         36967 non-null  object
#  2   description                  36967 non-null  object
#  3   neighborhood_overview        36967 non-null  object
#  4   picture_url                  36967 non-null  object
#  5   host_name                    36967 non-null  object
#  6   host_since                   36967 non-null  object
#  7   host_about                   36967 non-null  object
#  8   host_response_time           36967 non-null  object
#  9   host_is_superhost            36967 non-null  object
#  10  host_verifications           36967 non-null  object
#  11  host_has_profile_pic         36967 non-null  object
#  12  host_identity_verified       36967 non-null  object
# ...

# %%
freq_tbl(rio)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   25/09/2024      23695    0.640977         0.640977
# 1   26/09/2024      13271    0.358996         0.999973
# 2   29/09/2024          1    0.000027         1.000000
#
# ----------------------------------------------------------------
#
#                                                     name  frequency  \
# 0                              Apartamento em Copacabana        112
# 1                                   Quarto em Copacabana         43
# 2                               Apartamento aconchegante         36
# 3                   Lindo Flat Vista Mar Barra da Tijuca         33
# 4                                 Apartamento Copacabana         32
# ...                                                  ...        ...
# 35116  1 CoZy APaRTMeNT IPaNeMa P-9 NeaR THe BeaCH/La...          1
# 35117   2 quartos em amplo condomÃ­nio verde com piscina          1
# ...

# %%
tabla3=freq_tbl(rio['host_since'])
tabla3=tabla3.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla3[tabla3['frequency']>1]
filtro_index=filtro.set_index('host_since')
filtro_index
# Out:
#             frequency
# host_since
# 19/04/2013        220
# 24/08/2016        160
# 27/10/2015        155
# 15/04/2014        128
# 21/03/2012        119
# ...               ...
# 14/10/2016          2
# 16/05/2012          2
# 14/10/2017          2
# 02/10/2022          2
# 16/05/2020          2
#
# [4198 rows x 1 columns]

# %%
filtro_index.plot(kind='area', figsize=(10,4), alpha=0.5, color='red')
# Out:
# <Axes: xlabel='host_since'>

# %%
tabla3=freq_tbl(rio['host_response_time'])
tabla3=tabla3.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla3[tabla3['frequency']>1]
filtro_index=filtro.set_index('host_response_time')
filtro_index
# Out:
#                     frequency
# host_response_time
# within an hour          19227
# within a few hours       6136
# SIN INFORMACION          5068
# within a day             3712
# a few days or more       2824

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Tiempo de respuesta promedio')
plt.xlabel('Tiempos de respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla4=freq_tbl(rio['host_is_superhost'])
tabla4=tabla4.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla4[tabla4['frequency']>1]
filtro_index=filtro.set_index('host_is_superhost')
filtro_index
# Out:
#                    frequency
# host_is_superhost
# f                      24960
# t                      11041
# SIN INFORMACION          966

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla5=freq_tbl(rio['host_verifications'])
tabla5=tabla5.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla5[tabla5['frequency']>30]
filtro_index=filtro.set_index('host_verifications')
filtro_index
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                    28961
# ['phone']                              5395
# ['email', 'phone', 'work_email']       2376
# ['phone', 'work_email']                 165
# ['email']                                47

# %%
filtro_index.plot(kind='area', figsize=(10,4), alpha = 0.5, color='purple')
# Out:
# <Axes: xlabel='host_verifications'>

# %%
tabla6=freq_tbl(rio['host_has_profile_pic'])
tabla6=tabla6.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla6[tabla6['frequency']>1]
filtro_index=filtro.set_index('host_has_profile_pic')
filtro_index
# Out:
#                       frequency
# host_has_profile_pic
# t                         35789
# f                          1178

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla7=freq_tbl(rio['host_identity_verified'])
tabla7=tabla7.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla7[tabla7['frequency']>1]
filtro_index=filtro.set_index('host_identity_verified')
filtro_index
# Out:
#                         frequency
# host_identity_verified
# t                           30916
# f                            6051

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla8=freq_tbl(rio['property_type'])
tabla8=tabla8.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla8[tabla8['frequency']>10]
filtro_index=filtro.set_index('property_type')
filtro_index
# Out:
#                                     frequency
# property_type
# Entire rental unit                      23478
# Private room in rental unit              4419
# Entire home                              1744
# Entire condo                             1732
# Private room in home                     1290
# Entire loft                               752
# Entire serviced apartment                 751
# Private room in condo                     401
# Private room in bed and breakfast         316
# Room in hotel                             303
# Shared room in rental unit                241
# Shared room in home                       154
# Entire guesthouse                         119
# Private room in guest suite                97
# Entire villa                               93
# Private room in guesthouse                 91
# Room in aparthotel                         91
# Shared room in bed and breakfast           85
# Private room in serviced apartment         67
# ...

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Tipos de propiedad')
plt.xlabel('Propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla9=freq_tbl(rio['room_type'])
tabla9=tabla9.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla9[tabla9['frequency']>1]
filtro_index=filtro.set_index('room_type')
filtro_index
# Out:
#                  frequency
# room_type
# Entire home/apt      29079
# Private room          7231
# Shared room            629
# Hotel room              28

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Tipos de Habitación')
plt.xlabel('Habitación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla10=freq_tbl(rio['amenities'])
# tabla10=tabla10.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla10[tabla10['frequency']>1]
filtro_index=filtro.set_index('amenities')
filtro_index
# Out:
#                                                     frequency  percentage  \
# amenities
# ["Air conditioning", "Wifi", "Kitchen", "TV", "...        181    0.004896
# ["Air conditioning", "Wifi", "TV", "Kitchen"]             157    0.004247
# []                                                        127    0.003435
# ["Air conditioning", "Wifi", "Kitchen", "TV", "...         76    0.002056
# ["Washer", "Wifi", "TV", "Kitchen"]                        50    0.001353
# ...                                                       ...         ...
# ["Air conditioning", "Wifi", "Dedicated workspa...          2    0.000054
# ["Air conditioning", "Wifi", "Iron", "Kitchen",...          2    0.000054
# ["Air conditioning", "Wifi", "Hot tub", "Self c...          2    0.000054
# ["Air conditioning", "Wifi", "Outdoor shower", ...          2    0.000054
# ["Air conditioning", "Wifi", "Outdoor shower", ...          2    0.000054
#
#                                                     cumulative_perc
# ...

# %%
tabla10.plot("frequency", "cumulative_perc", kind="scatter",  color='purple')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla11=freq_tbl(rio['calendar_updated'])
#tabla8=tabla8.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla11[tabla11['frequency']>1]
filtro_index=filtro.set_index('calendar_updated')
filtro_index
# Out:
#                   frequency  percentage  cumulative_perc
# calendar_updated
# SIN INFORMACION       36967         1.0              1.0

# %%
# tabla11.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5), color='red')
tabla11.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5), cmap="Purples")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla12=freq_tbl(rio['has_availability'])
tabla12=tabla12.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla12[tabla12['frequency']>1]
filtro_index=filtro.set_index('has_availability')
filtro_index
# Out:
#                   frequency
# has_availability
# t                     36625
# SIN INFORMACION         339
# f                         3

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla13=freq_tbl(rio['instant_bookable'])
tabla13=tabla13.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla13[tabla13['frequency']>1]
filtro_index=filtro.set_index('instant_bookable')
filtro_index
# Out:
#                   frequency
# instant_bookable
# f                     28675
# t                      8292

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla14=freq_tbl(rio['name'])
tabla14=tabla14.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla14[tabla14['frequency']>20]
filtro_index=filtro.set_index('name')
filtro_index
# Out:
#                                       frequency
# name
# Apartamento em Copacabana                   112
# Quarto em Copacabana                         43
# Apartamento aconchegante                     36
# Lindo Flat Vista Mar Barra da Tijuca         33
# Apartamento Copacabana                       32
# Apartamento em Rio de Janeiro                22

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla15=freq_tbl(rio['license'])
#tabla8=tabla8.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla15[tabla15['frequency']>1]
filtro_index=filtro.set_index('license')
filtro_index
# Out:
#                  frequency  percentage  cumulative_perc
# license
# SIN INFORMACION      36967         1.0              1.0

# %%
tabla15.plot("frequency","cumulative_perc", kind="scatter", color='purple')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
tabla16=freq_tbl(rio['last_scraped'])
#tabla16=tabla16.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla16[tabla16['frequency']>1]
filtro_index=filtro.set_index('last_scraped')
filtro_index
# Out:
#               frequency  percentage  cumulative_perc
# last_scraped
# 25/09/2024        23695    0.640977         0.640977
# 26/09/2024        13271    0.358996         0.999973

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla17=freq_tbl(rio['host_name'])
tabla17=tabla17.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla17[tabla17['frequency']>250]
filtro_index=filtro.set_index('host_name')
filtro_index
# Out:
#            frequency
# host_name
# Daniel           375
# Rafael           321
# Rodrigo          316
# Ricardo          268
# Pedro            254
# Marcelo          251
# Felipe           251

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Nombre del anfitrión')
plt.xlabel('Nombre anfitrion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla18=freq_tbl(rio['last_review'])
tabla18=tabla18.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla18[tabla18['frequency']>50]
filtro_index=filtro.set_index('last_review')
filtro_index
# Out:
#                  frequency
# last_review
# SIN INFORMACION       8931
# 22/09/2024            2218
# 23/09/2024            2009
# 15/09/2024            1729
# 16/09/2024            1619
# ...                    ...
# 23/02/2023              60
# 31/07/2024              59
# 29/08/2024              58
# 27/07/2024              55
# 12/08/2024              52
#
# [83 rows x 1 columns]

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Fechas de las últimas reseñas')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla19=freq_tbl(rio['neighbourhood'])
# tabla19=tabla19.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla19[tabla19['frequency']>220]
filtro_index=filtro.set_index('neighbourhood')
filtro_index
# Out:
#                                                   frequency  percentage  \
# neighbourhood
# SIN INFORMACION                                       20018    0.541510
# Rio de Janeiro, Brazil                                10606    0.286905
# Copacabana, Rio de Janeiro, Brazil                     1839    0.049747
# Barra da Tijuca, Rio de Janeiro, Brazil                 587    0.015879
# Rio, Rio de Janeiro, Brazil                             485    0.013120
# Ipanema, Rio de Janeiro, Brazil                         481    0.013012
# Recreio dos Bandeirantes, Rio de Janeiro, Brazil        259    0.007006
# Botafogo, Rio de Janeiro, Brazil                        257    0.006952
# Leblon, Rio de Janeiro, Brazil                          256    0.006925
# Centro, Rio de Janeiro, Brazil                          224    0.006059
#
#                                                   cumulative_perc
# neighbourhood
# SIN INFORMACION                                          0.541510
# ...

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Vecindario general del alojamiento')
plt.xlabel('Nombre')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
tabla20=freq_tbl(rio['calendar_last_scraped'])
tabla20=tabla20.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla20[tabla20['frequency']>50]
filtro_index=filtro.set_index('calendar_last_scraped')
filtro_index
# Out:
#                        frequency
# calendar_last_scraped
# 25/09/2024                 23710
# 26/09/2024                 13256

# %%
filtro_index["frequency"].plot(kind='pie', colors= ['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
tabla21=freq_tbl(rio['description'])
# tabla10=tabla10.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla21[tabla21['frequency']>1]
filtro_index=filtro.set_index('description')
filtro_index
# Out:
#                                                     frequency  percentage  \
# description
# SIN INFORMACION                                          1207    0.032651
# Relax with the whole family in this quiet home.           155    0.004193
# Relax with the whole family in this quiet accom...        138    0.003733
# Embrace simplicity in this quiet and well-locat...        107    0.002894
# You will have a great time in this comfortable ...         87    0.002353
# ...                                                       ...         ...
# Independent rooms with direct exit to the outsi...          2    0.000054
# Great apartment in Barra da Tijuca, with 3 suit...          2    0.000054
# Come live in the heart of Ipanema. Overlooking ...          2    0.000054
# Would you like to enjoy your stay in the most e...          2    0.000054
# My space is good for couples.                               2    0.000054
#
# ...

# %%
tabla21.plot("frequency", "cumulative_perc", kind="scatter",  color='purple')
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# **VARIABLES NO CATEGORICAS**

# %%
valores_nulos=rio.isnull().sum()
valores_nulos
# Out:
# last_scraped                   0
# name                           0
# description                    0
# neighborhood_overview          0
# picture_url                    0
# host_name                      0
# host_since                     0
# host_about                     0
# host_response_time             0
# host_is_superhost              0
# host_verifications             0
# host_has_profile_pic           0
# host_identity_verified         0
# neighbourhood                  0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# calendar_updated               0
# has_availability               0
# calendar_last_scraped          0
# last_review                    0
# license                        0
# instant_bookable               0
# id                             0
# host_response_rate             0
# host_acceptance_rate           0
# host_listings_count            0
# ...

# %%
rio['host_acceptance_rate'].info()
n=36967
Max = rio['host_acceptance_rate'].max()
Min = rio['host_acceptance_rate'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [0.39, 1.0]

# %%
R = Max - Min
R
# Out:
# 0.61

# %%
ni = 1+3.32*np.log10(n)
ni
# Out:
# 16.165143168909132

# %%
i = R/12
i
# Out:
# 0.050833333333333335

# %%
intervalos = np.linspace(0.38, 1, 12)
intervalos
# Out:
# array([0.38      , 0.43636364, 0.49272727, 0.54909091, 0.60545455,
#        0.66181818, 0.71818182, 0.77454545, 0.83090909, 0.88727273,
#        0.94363636, 1.        ])

# %%
categorias = ["Prácticamente no acepta reservas","Raramente disponible", "Difícil de reservar", "Pocas reservas aceptadas", "Disponibilidad limitada", "Acepta algunas reservas", "Buena disponibilidad","La mayoría de reservas aceptadas","Alta disponibilidad","Disponibilidad casi total","Siempre disponible para reservas"]

# %%
rio['host_acceptance_rate'] = pd.cut(x = rio['host_acceptance_rate'], bins=intervalos, labels = categorias)
rio['host_acceptance_rate']
# Out:
# 0                     Alta disponibilidad
# 1               Disponibilidad casi total
# 2                    Buena disponibilidad
# 3        Siempre disponible para reservas
# 4                 Acepta algunas reservas
#                        ...
# 36962    Siempre disponible para reservas
# 36963           Disponibilidad casi total
# 36964           Disponibilidad casi total
# 36965           Disponibilidad casi total
# 36966           Disponibilidad casi total
# Name: host_acceptance_rate, Length: 36967, dtype: category
# Categories (11, object): ['Prácticamente no acepta reservas' < 'Raramente disponible' < 'Difícil de reservar' < 'Pocas reservas aceptadas' ... 'La mayoría de reservas aceptadas' < 'Alta disponibilidad' < 'Disponibilidad casi total' < 'Siempre disponible para reservas']

# %%
tabla1=freq_tbl(rio['host_acceptance_rate'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('host_acceptance_rate')
filtro_index
# Out:
#                                   frequency
# host_acceptance_rate
# Siempre disponible para reservas      14375
# Disponibilidad casi total             11650
# La mayoría de reservas aceptadas       2007
# Alta disponibilidad                    1783
# Acepta algunas reservas                1539
# Buena disponibilidad                   1469
# Difícil de reservar                    1228
# Pocas reservas aceptadas                988
# Disponibilidad limitada                 747
# Prácticamente no acepta reservas        647
# Raramente disponible                    534

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Taza de aceptación de reservas')
plt.xlabel('Reservas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['host_listings_count'].info()
n = 36967
Max = rio['host_listings_count'].max()
Min = rio['host_listings_count'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: host_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [0.0, 13.0]

# %%
R = Max - Min
R
# Out:
# 13.0

# %%
i = R/12
i
# Out:
# 1.0833333333333333

# %%
intervalos = np.linspace(-0.1, 13, 12)
intervalos
# Out:
# array([-0.1       ,  1.09090909,  2.28181818,  3.47272727,  4.66363636,
#         5.85454545,  7.04545455,  8.23636364,  9.42727273, 10.61818182,
#        11.80909091, 13.        ])

# %%
categorias=["Dueño de una sola propiedad","Manejo de pocas propiedades","Pequeña cartera de alojamientos","Inicio de un negocio de hospedaje","Expansión moderada","Gestión de múltiples propiedades","Negocio en crecimiento","Administración a gran escala","Estructura empresarial fuerte","Alcance significativo en varias zonas","Nivel de hotelería profesional"]

# %%
rio['host_listings_count'] = pd.cut(x = rio['host_listings_count'], bins=intervalos, labels = categorias)
rio['host_listings_count']
# Out:
# 0               Nivel de hotelería profesional
# 1              Pequeña cartera de alojamientos
# 2        Alcance significativo en varias zonas
# 3                  Dueño de una sola propiedad
# 4                  Dueño de una sola propiedad
#                          ...
# 36962          Pequeña cartera de alojamientos
# 36963              Dueño de una sola propiedad
# 36964        Inicio de un negocio de hospedaje
# 36965              Manejo de pocas propiedades
# 36966         Gestión de múltiples propiedades
# Name: host_listings_count, Length: 36967, dtype: category
# Categories (11, object): ['Dueño de una sola propiedad' < 'Manejo de pocas propiedades' < 'Pequeña cartera de alojamientos' < 'Inicio de un negocio de hospedaje' ... 'Administración a gran escala' < 'Estructura empresarial fuerte' < 'Alcance significativo en varias zonas' < 'Nivel de hotelería profesional']

# %%
tabla1=freq_tbl(rio['host_listings_count'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('host_listings_count')
filtro_index
# Out:
#                                        frequency
# host_listings_count
# Dueño de una sola propiedad                14534
# Pequeña cartera de alojamientos             8993
# Manejo de pocas propiedades                 6140
# Inicio de un negocio de hospedaje           1929
# Gestión de múltiples propiedades            1637
# Expansión moderada                          1195
# Negocio en crecimiento                       669
# Nivel de hotelería profesional               573
# Administración a gran escala                 524
# Estructura empresarial fuerte                513
# Alcance significativo en varias zonas        260

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="red")
plt.title('Número de anuncios del anfitrión')
plt.xlabel('Anuncios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['accommodates'].info()
n=36967
max=rio['accommodates'].max()
min=rio['accommodates'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [1.0, 9.0]

# %%
r=max-min
r
# Out:
# 8.0

# %%
i=r/12
i
# Out:
# 0.6666666666666666

# %%
intervalos=np.linspace(0.99, 7, 12)
intervalos
# Out:
# array([0.99      , 1.53636364, 2.08272727, 2.62909091, 3.17545455,
#        3.72181818, 4.26818182, 4.81454545, 5.36090909, 5.90727273,
#        6.45363636, 7.        ])

# %%
categorias= ["Individual", "Doble", "Pequeño grupo", "Familiar","Espacioso","Amplio","Grupo pequeño","Gran mediano", "Pequeño grande", "Eveno pequeño", "Alojamiento grande"]

# %%
rio['accommodates']=pd.cut(x=rio['accommodates'], bins=intervalos, labels=categorias)
rio['accommodates']
# Out:
# 0                Doble
# 1                Doble
# 2               Amplio
# 3               Amplio
# 4                Doble
#              ...
# 36962         Familiar
# 36963    Eveno pequeño
# 36964           Amplio
# 36965            Doble
# 36966           Amplio
# Name: accommodates, Length: 36967, dtype: category
# Categories (11, object): ['Individual' < 'Doble' < 'Pequeño grupo' < 'Familiar' ... 'Gran mediano' < 'Pequeño grande' < 'Eveno pequeño' < 'Alojamiento grande']

# %%
tabla1=freq_tbl(rio['accommodates'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('accommodates')
filtro_index
# Out:
#                     frequency
# accommodates
# Amplio                  10881
# Doble                    9971
# Familiar                 4388
# Eveno pequeño            4024
# Gran mediano             2880
# Individual               1589
# Espacioso                1275
# Alojamiento grande        696

# %%
filtro_index['frequency'].plot(kind='pie', figsize=(10,5), colors=['#800080', '#9932CC', '#BA55D3', '#DA70D6'], autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
rio['bathrooms'].info()
n=36967
max=rio['bathrooms'].max()
min=rio['bathrooms'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: bathrooms
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [0.0, 3.5]

# %%
r=max-min
r
# Out:
# 3.5

# %%
i=r/8
i
# Out:
# 0.4375

# %%
intervalos=np.linspace(-0.1, 3.5, 9)
intervalos
# Out:
# array([-0.1 ,  0.35,  0.8 ,  1.25,  1.7 ,  2.15,  2.6 ,  3.05,  3.5 ])

# %%
categorias=["Sin baño","Medio Baño","Baño completo","Baño y medio","Dos baños completos","Dos baños y medio","Tres baños completos","Tres baños y medio"]

# %%
rio['bathrooms'] = pd.cut(x = rio['bathrooms'], bins=intervalos, labels = categorias)
rio['bathrooms']
# Out:
# 0        Dos baños completos
# 1              Baño completo
# 2              Baño completo
# 3        Dos baños completos
# 4              Baño completo
#                 ...
# 36962          Baño completo
# 36963          Baño completo
# 36964          Baño completo
# 36965          Baño completo
# 36966          Baño completo
# Name: bathrooms, Length: 36967, dtype: category
# Categories (8, object): ['Sin baño' < 'Medio Baño' < 'Baño completo' < 'Baño y medio' < 'Dos baños completos' < 'Dos baños y medio' < 'Tres baños completos' < 'Tres baños y medio']

# %%
tabla1=freq_tbl(rio['bathrooms'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('bathrooms')
filtro_index
# Out:
#                       frequency
# bathrooms
# Baño completo             21306
# Dos baños completos        7225
# Baño y medio               3158
# Sin baño                   1969
# Tres baños completos       1599
# Dos baños y medio          1098
# Tres baños y medio          412
# Medio Baño                  200

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Número de baños en los alojamientos')
plt.xlabel('Número de baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['beds'].info()
n=36967
max=rio['beds'].max()
min=rio['beds'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [0.0, 6.0]

# %%
r=max-min
r
# Out:
# 6.0

# %%
i=r/6
i
# Out:
# 1.0

# %%
intervalos=np.linspace(-0.1, 6, 8)
intervalos
# Out:
# array([-0.1       ,  0.77142857,  1.64285714,  2.51428571,  3.38571429,
#         4.25714286,  5.12857143,  6.        ])

# %%
categorias=["Sin camas", "Una cama", "Dos camas", "Tres camas", "Cuatro camas", "Cinco camas", "Seis camas"]

# %%
rio['beds'] = pd.cut(x = rio['beds'], bins=intervalos, labels = categorias)
rio['beds']
# Out:
# 0            Una cama
# 1        Cuatro camas
# 2            Una cama
# 3           Dos camas
# 4            Una cama
#              ...
# 36962      Tres camas
# 36963       Dos camas
# 36964       Dos camas
# 36965        Una cama
# 36966       Dos camas
# Name: beds, Length: 36967, dtype: category
# Categories (7, object): ['Sin camas' < 'Una cama' < 'Dos camas' < 'Tres camas' < 'Cuatro camas' < 'Cinco camas' < 'Seis camas']

# %%
tabla1=freq_tbl(rio['beds'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('beds')
filtro_index
# Out:
#               frequency
# beds
# Una cama          12095
# Dos camas         11541
# Tres camas         5575
# Cuatro camas       3080
# Sin camas          2458
# Cinco camas        1406
# Seis camas          812

# %%
filtro_index["frequency"].plot(kind='pie', colors=['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
rio['price'].info()
n=36967
max=rio['price'].max()
min=rio['price'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [33.0, 1384.0]

# %%
r=max-min
r
# Out:
# 1351.0

# %%
i=r/12
i
# Out:
# 112.58333333333333

# %%
intervalos=np.linspace(32.99, 1384, 12)
intervalos
# Out:
# array([  32.99      ,  155.80909091,  278.62818182,  401.44727273,
#         524.26636364,  647.08545455,  769.90454545,  892.72363636,
#        1015.54272727, 1138.36181818, 1261.18090909, 1384.        ])

# %%
categorias = [
    "Precio no disponible", 
    "Precio muy bajo", 
    "Precio bajo", 
    "Precio razonable", 
    "Precio moderado", 
    "Precio aceptable", 
    "Precio alto", 
    "Precio muy alto", 
    "Precio muy elevado", 
    "Precio elevado", 
    "Precio premium",
]

# %%
rio['price'] = pd.cut(x = rio['price'], bins=intervalos, labels = categorias)
rio['price']
# Out:
# 0             Precio muy bajo
# 1                 Precio bajo
# 2                 Precio bajo
# 3            Precio razonable
# 4                 Precio bajo
#                  ...
# 36962    Precio no disponible
# 36963         Precio muy bajo
# 36964         Precio muy bajo
# 36965         Precio muy bajo
# 36966             Precio bajo
# Name: price, Length: 36967, dtype: category
# Categories (11, object): ['Precio no disponible' < 'Precio muy bajo' < 'Precio bajo' < 'Precio razonable' ... 'Precio muy alto' < 'Precio muy elevado' < 'Precio elevado' < 'Precio premium']

# %%
tabla1=freq_tbl(rio['price'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('price')
filtro_index
# Out:
#                       frequency
# price
# Precio muy bajo            9615
# Precio bajo                7182
# Precio razonable           6438
# Precio no disponible       4514
# Precio aceptable           3352
# Precio moderado            2224
# Precio muy alto            1228
# Precio alto                1185
# Precio elevado              502
# Precio muy elevado          435
# Precio premium              292

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Rango de precios')
plt.xlabel('Precios')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['maximum_nights'].info()
n=36967
max=rio['maximum_nights'].max()
min=rio['maximum_nights'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: maximum_nights
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [1.0, 800.0]

# %%
r=max-min
r
# Out:
# 799.0

# %%
i=r/12
i
# Out:
# 66.58333333333333

# %%
intervalos=np.linspace(0.99, 800, 12)
intervalos
# Out:
# array([  0.99      ,  73.62727273, 146.26454545, 218.90181818,
#        291.53909091, 364.17636364, 436.81363636, 509.45090909,
#        582.08818182, 654.72545455, 727.36272727, 800.        ])

# %%
categorias = [
    "Básico", 
    "Accesible", 
    "Confortable", 
    "Destacado", 
    "Exquisito", 
    "Ideal", 
    "Relajante", 
    "Premium", 
    "Excepcional", 
    "Distinguido", 
    "Máximo"
]

# %%
rio['maximum_nights'] = pd.cut(x = rio['maximum_nights'], bins=intervalos, labels = categorias)
rio['maximum_nights']
# Out:
# 0        Exquisito
# 1            Ideal
# 2        Accesible
# 3           Básico
# 4           Básico
#            ...
# 36962        Ideal
# 36963        Ideal
# 36964        Ideal
# 36965        Ideal
# 36966        Ideal
# Name: maximum_nights, Length: 36967, dtype: category
# Categories (11, object): ['Básico' < 'Accesible' < 'Confortable' < 'Destacado' ... 'Premium' < 'Excepcional' < 'Distinguido' < 'Máximo']

# %%
tabla1=freq_tbl(rio['maximum_nights'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('maximum_nights')
filtro_index
# Out:
#                 frequency
# maximum_nights
# Ideal               12946
# Básico               9946
# Confortable          8383
# Accesible            4752
# Máximo                514
# Exquisito             245
# Distinguido            87
# Destacado              56
# Relajante              25
# Excepcional             9
# Premium                 4

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Número de noches máximas')
plt.xlabel('Noches máximas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['availability_365'].info()
n=36967
max=rio['availability_365'].max()
min=rio['availability_365'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  int64
# dtypes: int64(1)
# memory usage: 288.9 KB
# [0, 365]

# %%
R = max - min
R
# Out:
# 365

# %%
i = R/12
i
# Out:
# 30.416666666666668

# %%
intervalos = np.linspace(-0.1, 365, 12)
intervalos
# Out:
# array([-1.00000000e-01,  3.30909091e+01,  6.62818182e+01,  9.94727273e+01,
#         1.32663636e+02,  1.65854545e+02,  1.99045455e+02,  2.32236364e+02,
#         2.65427273e+02,  2.98618182e+02,  3.31809091e+02,  3.65000000e+02])

# %%
categorias = ["No disponible", 
              "Disponibilidad baja", 
              "Disponible en temporadas", 
              "Parcialmete disponible", 
              "Moderadamente disponible", 
              "Disponibilidad promedio", 
              "Buena disponibilidad", 
              "Alta disponibilidad", 
              "Mayormente disponible", 
              "Casi siempre disponible", 
              "Siempre disponible"]

# %%
rio['availability_365'] = pd.cut(x = rio['availability_365'], bins=intervalos, labels = categorias)
rio['availability_365']
# Out:
# 0              Siempre disponible
# 1              Siempre disponible
# 2        Disponible en temporadas
# 3        Moderadamente disponible
# 4           Mayormente disponible
#                    ...
# 36962     Disponibilidad promedio
# 36963          Siempre disponible
# 36964          Siempre disponible
# 36965     Casi siempre disponible
# 36966          Siempre disponible
# Name: availability_365, Length: 36967, dtype: category
# Categories (11, object): ['No disponible' < 'Disponibilidad baja' < 'Disponible en temporadas' < 'Parcialmete disponible' ... 'Alta disponibilidad' < 'Mayormente disponible' < 'Casi siempre disponible' < 'Siempre disponible']

# %%
tabla1=freq_tbl(rio['availability_365'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('availability_365')
filtro_index
# Out:
#                           frequency
# availability_365
# Siempre disponible             8948
# Disponible en temporadas       5658
# No disponible                  3484
# Disponibilidad promedio        3194
# Mayormente disponible          2929
# Moderadamente disponible       2666
# Alta disponibilidad            2620
# Disponibilidad baja            2344
# Parcialmete disponible         2251
# Casi siempre disponible        1536
# Buena disponibilidad           1337

# %%
filtro_index.plot(kind='bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Disponibilidad en el año del alojamiento')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['host_response_rate'].info()
n=36967
max=rio['host_response_rate'].max()
min=rio['host_response_rate'].min()
Limites=[min,max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  int64
# dtypes: int64(1)
# memory usage: 288.9 KB
# [1, 1]

# %%
R = max - min
R
# Out:
# 0

# %%
i = R/12
i
# Out:
# 0.0

# %%
intervalos = np.linspace(0.99, 1, 2)
intervalos
# Out:
# array([0.99, 1.  ])

# %%
categorias = ["Atención inmediata"]

# %%
rio['host_response_rate'] = pd.cut(x = rio['host_response_rate'], bins=intervalos, labels = categorias)
rio['host_response_rate']
# Out:
# 0        Atención inmediata
# 1        Atención inmediata
# 2        Atención inmediata
# 3        Atención inmediata
# 4        Atención inmediata
#                 ...
# 36962    Atención inmediata
# 36963    Atención inmediata
# 36964    Atención inmediata
# 36965    Atención inmediata
# 36966    Atención inmediata
# Name: host_response_rate, Length: 36967, dtype: category
# Categories (1, object): ['Atención inmediata']

# %%
tabla1=freq_tbl(rio['host_response_rate'])
tabla1=tabla1.drop(['percentage','cumulative_perc'], axis=1)
filtro=tabla1[tabla1['frequency']>1]
filtro_index=filtro.set_index('host_response_rate')
filtro_index
# Out:
#                     frequency
# host_response_rate
# Atención inmediata      36967

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Tasa de respuesta del anfitrión')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['number_of_reviews'].info()
n = 36967
Max = rio['number_of_reviews'].max()
Min = rio['number_of_reviews'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  int64
# dtypes: int64(1)
# memory usage: 288.9 KB
# [0, 58]

# %%
R = Max - Min
R
# Out:
# 58

# %%
i = R/12
i
# Out:
# 4.833333333333333

# %%
intervalos = np.linspace(-0.1, 58, 12)
intervalos
# Out:
# array([-0.1       ,  5.18181818, 10.46363636, 15.74545455, 21.02727273,
#        26.30909091, 31.59090909, 36.87272727, 42.15454545, 47.43636364,
#        52.71818182, 58.        ])

# %%
categorias = ["0 Reseñas","1-5 Reseñas", "6-10 Reseñas", "11-20 Reseñas", "21-40 Reseñas", "41-60 Reseñas", "61-100 Reseñas","101-150 Reseñas","151-200 Reseñas","201-300 Reseñas","300+ Reseñas"]

# %%
rio['number_of_reviews'] = pd.cut(x = rio['number_of_reviews'], bins=intervalos, labels = categorias)
rio['number_of_reviews']
# Out:
# 0        61-100 Reseñas
# 1             0 Reseñas
# 2        61-100 Reseñas
# 3        61-100 Reseñas
# 4        61-100 Reseñas
#               ...
# 36962         0 Reseñas
# 36963         0 Reseñas
# 36964         0 Reseñas
# 36965         0 Reseñas
# 36966         0 Reseñas
# Name: number_of_reviews, Length: 36967, dtype: category
# Categories (11, object): ['0 Reseñas' < '1-5 Reseñas' < '6-10 Reseñas' < '11-20 Reseñas' ... '101-150 Reseñas' < '151-200 Reseñas' < '201-300 Reseñas' < '300+ Reseñas']

# %%
tabla2 = freq_tbl(rio['number_of_reviews'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('number_of_reviews')
filtro_index
# Out:
#                    frequency  percentage  cumulative_perc
# number_of_reviews
# 0 Reseñas              18815    0.508967         0.508967
# 1-5 Reseñas             8001    0.216436         0.725404
# 6-10 Reseñas            2438    0.065951         0.791354
# 11-20 Reseñas           1979    0.053534         0.844889
# 21-40 Reseñas           1271    0.034382         0.879271
# 41-60 Reseñas           1072    0.028999         0.908270
# 61-100 Reseñas           860    0.023264         0.931534
# 101-150 Reseñas          833    0.022534         0.954067
# 151-200 Reseñas          613    0.016582         0.970649
# 300+ Reseñas             553    0.014959         0.985609
# 201-300 Reseñas          532    0.014391         1.000000

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Número total de reseñas del anuncio.')
plt.xlabel('Reseña')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['review_scores_location'].info()
n = 36967
Max = rio['review_scores_location'].max()
Min = rio['review_scores_location'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [4.76, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.2400000000000002

# %%
i = R/12
i
# Out:
# 0.020000000000000018

# %%
intervalos = np.linspace(4.75, 5.0, 12)
intervalos
# Out:
# array([4.75      , 4.77272727, 4.79545455, 4.81818182, 4.84090909,
#        4.86363636, 4.88636364, 4.90909091, 4.93181818, 4.95454545,
#        4.97727273, 5.        ])

# %%
categorias = ["0-1 Muy Mala", "1-2 Mala", "2-3 Deficiente", "3-4 Regular", "4-5 Aceptable", 
              "5-6 Promedio", "6-7 Buena", "7-8 Muy Buena", "8-9 Excelente", 
              "9-9.5 Destacada", "9.5-10 Perfecta"]

# %%
rio['review_scores_location'] = pd.cut(x = rio['review_scores_location'], bins=intervalos, labels = categorias)
rio['review_scores_location']
# Out:
# 0           6-7 Buena
# 1           6-7 Buena
# 2           6-7 Buena
# 3         3-4 Regular
# 4        0-1 Muy Mala
#              ...
# 36962       6-7 Buena
# 36963       6-7 Buena
# 36964       6-7 Buena
# 36965       6-7 Buena
# 36966       6-7 Buena
# Name: review_scores_location, Length: 36967, dtype: category
# Categories (11, object): ['0-1 Muy Mala' < '1-2 Mala' < '2-3 Deficiente' < '3-4 Regular' ... '7-8 Muy Buena' < '8-9 Excelente' < '9-9.5 Destacada' < '9.5-10 Perfecta']

# %%
tabla2 = freq_tbl(rio['review_scores_location'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('review_scores_location')
filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# review_scores_location
# 6-7 Buena                   14431    0.390375         0.390375
# 9.5-10 Perfecta             13432    0.363351         0.753726
# 7-8 Muy Buena                1968    0.053237         0.806963
# 8-9 Excelente                1582    0.042795         0.849758
# 9-9.5 Destacada              1483    0.040117         0.889875
# 3-4 Regular                   941    0.025455         0.915330
# 5-6 Promedio                  906    0.024508         0.939838
# 4-5 Aceptable                 864    0.023372         0.963210
# 2-3 Deficiente                684    0.018503         0.981713
# 1-2 Mala                      429    0.011605         0.993318
# 0-1 Muy Mala                  247    0.006682         1.000000

# %%
filtro_index["frequency"].plot(kind='pie', colors=['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
rio['review_scores_value'].info()
n = 36967
Max = rio['review_scores_value'].max()
Min = rio['review_scores_value'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [4.36, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.6399999999999997

# %%
i = R/12
i
# Out:
# 0.05333333333333331

# %%
intervalos = np.linspace(4.35, 5.0, 12)
intervalos
# Out:
# array([4.35      , 4.40909091, 4.46818182, 4.52727273, 4.58636364,
#        4.64545455, 4.70454545, 4.76363636, 4.82272727, 4.88181818,
#        4.94090909, 5.        ])

# %%
categorias = ["0-1 Muy Mala", "1-2 Mala", "2-3 Deficiente", "3-4 Regular", "4-5 Aceptable", 
              "5-6 Promedio", "6-7 Buena", "7-8 Muy Buena", "8-9 Excelente", 
              "9-9.5 Destacada", "9.5-10 Perfecta"]

# %%
rio['review_scores_value'] = pd.cut(x = rio['review_scores_value'], bins=intervalos, labels = categorias)
rio['review_scores_value']
# Out:
# 0          4-5 Aceptable
# 1           5-6 Promedio
# 2           5-6 Promedio
# 3        9-9.5 Destacada
# 4          4-5 Aceptable
#               ...
# 36962       5-6 Promedio
# 36963       5-6 Promedio
# 36964       5-6 Promedio
# 36965       5-6 Promedio
# 36966       5-6 Promedio
# Name: review_scores_value, Length: 36967, dtype: category
# Categories (11, object): ['0-1 Muy Mala' < '1-2 Mala' < '2-3 Deficiente' < '3-4 Regular' ... '7-8 Muy Buena' < '8-9 Excelente' < '9-9.5 Destacada' < '9.5-10 Perfecta']

# %%
tabla2 = freq_tbl(rio['review_scores_value'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('review_scores_value')
filtro_index
# Out:
#                      frequency  percentage  cumulative_perc
# review_scores_value
# 5-6 Promedio             10925    0.295534         0.295534
# 9.5-10 Perfecta           8796    0.237942         0.533476
# 7-8 Muy Buena             5402    0.146130         0.679606
# 8-9 Excelente             3016    0.081586         0.761192
# 9-9.5 Destacada           2573    0.069603         0.830795
# 6-7 Buena                 2290    0.061947         0.892742
# 2-3 Deficiente            1214    0.032840         0.925582
# 4-5 Aceptable             1187    0.032110         0.957692
# 3-4 Regular                807    0.021830         0.979522
# 1-2 Mala                   402    0.010875         0.990397
# 0-1 Muy Mala               355    0.009603         1.000000

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Calificación de la relación calidad-precio en las reseñas.')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['reviews_per_month'].info()
n = 36967
Max = rio['reviews_per_month'].max()
Min = rio['reviews_per_month'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [0.01, 2.55]

# %%
R = Max - Min
R
# Out:
# 2.54

# %%
i = R/12
i
# Out:
# 0.21166666666666667

# %%
intervalos = np.linspace(0, 2.55, 12)
intervalos
# Out:
# array([0.        , 0.23181818, 0.46363636, 0.69545455, 0.92727273,
#        1.15909091, 1.39090909, 1.62272727, 1.85454545, 2.08636364,
#        2.31818182, 2.55      ])

# %%
categorias = ["0.01-0.43 Sin reseñas frecuentes", 
              "0.44-0.86 Muy pocas reseñas", 
              "0.87-1.29 Pocas reseñas", 
              "1.30-1.72 Algunas reseñas", 
              "1.73-2.15 Moderadas reseñas", 
              "2.16-2.58 Frecuentes reseñas", 
              "2.59-3.00 Reseñas constantes", 
              "3.01-3.43 Muchas reseñas", 
              "3.44-3.86 Muy alta actividad", 
              "3.87-4.29 Extremadamente alto", 
              "4.30-4.72 Popularidad máxima"]

# %%
rio['reviews_per_month'] = pd.cut(x = rio['reviews_per_month'], bins=intervalos, labels = categorias)
rio['reviews_per_month']
# Out:
# 0        0.01-0.43 Sin reseñas frecuentes
# 1        0.01-0.43 Sin reseñas frecuentes
# 2        0.01-0.43 Sin reseñas frecuentes
# 3                 0.87-1.29 Pocas reseñas
# 4             0.44-0.86 Muy pocas reseñas
#                        ...
# 36962         1.73-2.15 Moderadas reseñas
# 36963         1.73-2.15 Moderadas reseñas
# 36964         1.73-2.15 Moderadas reseñas
# 36965         1.73-2.15 Moderadas reseñas
# 36966         1.73-2.15 Moderadas reseñas
# Name: reviews_per_month, Length: 36967, dtype: category
# Categories (11, object): ['0.01-0.43 Sin reseñas frecuentes' < '0.44-0.86 Muy pocas reseñas' < '0.87-1.29 Pocas reseñas' < '1.30-1.72 Algunas reseñas' ... '3.01-3.43 Muchas reseñas' < '3.44-3.86 Muy alta actividad' < '3.87-4.29 Extremadamente alto' < '4.30-4.72 Popularidad máxima']

# %%
tabla2 = freq_tbl(rio['reviews_per_month'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('reviews_per_month')
filtro_index
# Out:
#                                   frequency  percentage  cumulative_perc
# reviews_per_month
# 1.73-2.15 Moderadas reseñas           11570    0.312982         0.312982
# 0.01-0.43 Sin reseñas frecuentes       7096    0.191955         0.504937
# 1.30-1.72 Algunas reseñas              5349    0.144697         0.649633
# 0.44-0.86 Muy pocas reseñas            3911    0.105797         0.755431
# 0.87-1.29 Pocas reseñas                2645    0.071550         0.826981
# 2.16-2.58 Frecuentes reseñas           1415    0.038277         0.865258
# 3.44-3.86 Muy alta actividad           1363    0.036871         0.902129
# 2.59-3.00 Reseñas constantes           1185    0.032056         0.934185
# 3.01-3.43 Muchas reseñas               1012    0.027376         0.961560
# 3.87-4.29 Extremadamente alto           813    0.021993         0.983553
# 4.30-4.72 Popularidad máxima            608    0.016447         1.000000

# %%
filtro_index["frequency"].plot(kind='pie', colors=['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
rio['review_scores_communication'].info()
n = 36967
Max = rio['review_scores_communication'].max()
Min = rio['review_scores_communication'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [4.76, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.2400000000000002

# %%
i = R/12
i
# Out:
# 0.020000000000000018

# %%
intervalos = np.linspace(4.75, 5.0, 12)
intervalos
# Out:
# array([4.75      , 4.77272727, 4.79545455, 4.81818182, 4.84090909,
#        4.86363636, 4.88636364, 4.90909091, 4.93181818, 4.95454545,
#        4.97727273, 5.        ])

# %%
categorias = ["4.50-4.54 Comunicación deficiente", 
              "4.55-4.59 Muy mala comunicación", 
              "4.60-4.63 Comunicación insuficiente", 
              "4.64-4.68 Regular", 
              "4.69-4.72 Aceptable", 
              "4.73-4.77 Buena comunicación", 
              "4.78-4.81 Muy buena comunicación", 
              "4.82-4.86 Excelente comunicación", 
              "4.87-4.90 Comunicación destacada", 
              "4.91-4.95 Casi perfecta", 
              "4.96-5.00 Comunicación impecable"]

# %%
rio['review_scores_communication'] = pd.cut(x = rio['review_scores_communication'], bins=intervalos, labels = categorias)
rio['review_scores_communication']
# Out:
# 0                     4.69-4.72 Aceptable
# 1        4.96-5.00 Comunicación impecable
# 2            4.73-4.77 Buena comunicación
# 3        4.96-5.00 Comunicación impecable
# 4                       4.64-4.68 Regular
#                        ...
# 36962    4.78-4.81 Muy buena comunicación
# 36963    4.78-4.81 Muy buena comunicación
# 36964    4.78-4.81 Muy buena comunicación
# 36965    4.78-4.81 Muy buena comunicación
# 36966    4.78-4.81 Muy buena comunicación
# Name: review_scores_communication, Length: 36967, dtype: category
# Categories (11, object): ['4.50-4.54 Comunicación deficiente' < '4.55-4.59 Muy mala comunicación' < '4.60-4.63 Comunicación insuficiente' < '4.64-4.68 Regular' ... '4.82-4.86 Excelente comunicación' < '4.87-4.90 Comunicación destacada' < '4.91-4.95 Casi perfecta' < '4.96-5.00 Comunicación impecable']

# %%
tabla2 = freq_tbl(rio['review_scores_communication'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('review_scores_communication')
filtro_index
# Out:
#                                      frequency  percentage  cumulative_perc
# review_scores_communication
# 4.96-5.00 Comunicación impecable         15537    0.420294         0.420294
# 4.78-4.81 Muy buena comunicación         13600    0.367896         0.788189
# 4.82-4.86 Excelente comunicación          1740    0.047069         0.835258
# 4.91-4.95 Casi perfecta                   1435    0.038818         0.874077
# 4.87-4.90 Comunicación destacada          1319    0.035680         0.909757
# 4.64-4.68 Regular                          843    0.022804         0.932561
# 4.73-4.77 Buena comunicación               754    0.020397         0.952958
# 4.69-4.72 Aceptable                        675    0.018260         0.971218
# 4.60-4.63 Comunicación insuficiente        523    0.014148         0.985365
# 4.55-4.59 Muy mala comunicación            308    0.008332         0.993697
# 4.50-4.54 Comunicación deficiente          233    0.006303         1.000000

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Calificación de la comunicación en las reseñas.')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['review_scores_checkin'].info()
n = 36967
Max = rio['review_scores_checkin'].max()
Min = rio['review_scores_checkin'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [4.76, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.2400000000000002

# %%
i = R/12
i
# Out:
# 0.020000000000000018

# %%
intervalos = np.linspace(4.75, 5.0, 12)
intervalos
# Out:
# array([4.75      , 4.77272727, 4.79545455, 4.81818182, 4.84090909,
#        4.86363636, 4.88636364, 4.90909091, 4.93181818, 4.95454545,
#        4.97727273, 5.        ])

# %%
categorias = ["4.50-4.54 Registro deficiente", 
              "4.55-4.59 Registro muy malo", 
              "4.60-4.63 Registro insuficiente", 
              "4.64-4.68 Regular", 
              "4.69-4.72 Aceptable", 
              "4.73-4.77 Buen registro", 
              "4.78-4.81 Muy buen registro", 
              "4.82-4.86 Excelente registro", 
              "4.87-4.90 Registro destacado", 
              "4.91-4.95 Casi perfecto", 
              "4.96-5.00 Registro impecable"]

# %%
rio['review_scores_checkin'] = pd.cut(x = rio['review_scores_checkin'], bins=intervalos, labels = categorias)
rio['review_scores_checkin']
# Out:
# 0            4.78-4.81 Muy buen registro
# 1            4.78-4.81 Muy buen registro
# 2                      4.64-4.68 Regular
# 3           4.96-5.00 Registro impecable
# 4        4.60-4.63 Registro insuficiente
#                       ...
# 36962        4.78-4.81 Muy buen registro
# 36963        4.78-4.81 Muy buen registro
# 36964        4.78-4.81 Muy buen registro
# 36965        4.78-4.81 Muy buen registro
# 36966        4.78-4.81 Muy buen registro
# Name: review_scores_checkin, Length: 36967, dtype: category
# Categories (11, object): ['4.50-4.54 Registro deficiente' < '4.55-4.59 Registro muy malo' < '4.60-4.63 Registro insuficiente' < '4.64-4.68 Regular' ... '4.82-4.86 Excelente registro' < '4.87-4.90 Registro destacado' < '4.91-4.95 Casi perfecto' < '4.96-5.00 Registro impecable']

# %%
tabla2 = freq_tbl(rio['review_scores_checkin'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('review_scores_checkin')
filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# review_scores_checkin
# 4.96-5.00 Registro impecable         15566    0.421078         0.421078
# 4.78-4.81 Muy buen registro          13124    0.355019         0.776098
# 4.82-4.86 Excelente registro          1869    0.050559         0.826656
# 4.91-4.95 Casi perfecto               1581    0.042768         0.869424
# 4.87-4.90 Registro destacado          1495    0.040441         0.909866
# 4.64-4.68 Regular                      831    0.022480         0.932345
# 4.73-4.77 Buen registro                784    0.021208         0.953553
# 4.69-4.72 Aceptable                    700    0.018936         0.972489
# 4.60-4.63 Registro insuficiente        509    0.013769         0.986258
# 4.55-4.59 Registro muy malo            304    0.008224         0.994482
# 4.50-4.54 Registro deficiente          204    0.005518         1.000000

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Calificación del registro de entrada en las reseñas.')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
rio['review_scores_cleanliness'].info()
n = 36967
Max = rio['review_scores_cleanliness'].max()
Min = rio['review_scores_cleanliness'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [4.46, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.54

# %%
i = R/12
i
# Out:
# 0.045000000000000005

# %%
intervalos = np.linspace(4.45, 5.0, 12)
intervalos
# Out:
# array([4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 , 4.95,
#        5.  ])

# %%
categorias = [
    "4.43-4.48 Muy sucio", 
    "4.49-4.53 Sucio", 
    "4.54-4.59 Poco limpio", 
    "4.60-4.64 Regularmente limpio", 
    "4.65-4.69 Limpio", 
    "4.70-4.74 Bastante limpio", 
    "4.75-4.79 Muy limpio", 
    "4.80-4.84 Excelente limpieza", 
    "4.85-4.89 Impecable", 
    "4.90-4.94 Casi perfecto", 
    "4.95-5.00 Limpieza impecable"
]

# %%
rio['review_scores_cleanliness'] = pd.cut(x = rio['review_scores_cleanliness'], bins=intervalos, labels = categorias)
rio['review_scores_cleanliness']
# Out:
# 0               4.54-4.59 Poco limpio
# 1                 4.85-4.89 Impecable
# 2                4.75-4.79 Muy limpio
# 3        4.95-5.00 Limpieza impecable
# 4                4.75-4.79 Muy limpio
#                      ...
# 36962            4.75-4.79 Muy limpio
# 36963            4.75-4.79 Muy limpio
# 36964            4.75-4.79 Muy limpio
# 36965            4.75-4.79 Muy limpio
# 36966            4.75-4.79 Muy limpio
# Name: review_scores_cleanliness, Length: 36967, dtype: category
# Categories (11, object): ['4.43-4.48 Muy sucio' < '4.49-4.53 Sucio' < '4.54-4.59 Poco limpio' < '4.60-4.64 Regularmente limpio' ... '4.80-4.84 Excelente limpieza' < '4.85-4.89 Impecable' < '4.90-4.94 Casi perfecto' < '4.95-5.00 Limpieza impecable']

# %%
tabla2 = freq_tbl(rio['review_scores_cleanliness'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('review_scores_cleanliness')
filtro_index
# Out:
#                                frequency  percentage  cumulative_perc
# review_scores_cleanliness
# 4.95-5.00 Limpieza impecable       11334    0.306598         0.306598
# 4.75-4.79 Muy limpio               10562    0.285714         0.592312
# 4.85-4.89 Impecable                 5338    0.144399         0.736711
# 4.90-4.94 Casi perfecto             2476    0.066979         0.803690
# 4.80-4.84 Excelente limpieza        1763    0.047691         0.851381
# 4.70-4.74 Bastante limpio           1472    0.039819         0.891200
# 4.65-4.69 Limpio                    1331    0.036005         0.927205
# 4.43-4.48 Muy sucio                  916    0.024779         0.951984
# 4.54-4.59 Poco limpio                769    0.020802         0.972787
# 4.60-4.64 Regularmente limpio        683    0.018476         0.991262
# 4.49-4.53 Sucio                      323    0.008738         1.000000

# %%
filtro_index["frequency"].plot(kind='pie', colors=['#800080', '#9932CC', '#BA55D3', '#DA70D6'], figsize=(10,5), autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
rio['review_scores_accuracy'].info()
n = 36967
Max = rio['review_scores_accuracy'].max()
Min = rio['review_scores_accuracy'].min()
Limites = [Min, Max]
Limites
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36967 entries, 0 to 36966
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 36967 non-null  float64
# dtypes: float64(1)
# memory usage: 288.9 KB
# [4.5, 5.0]

# %%
R = Max - Min
R
# Out:
# 0.5

# %%
i = R/12
i
# Out:
# 0.041666666666666664

# %%
intervalos = np.linspace(4.49, 5.0, 12)
intervalos
# Out:
# array([4.49      , 4.53636364, 4.58272727, 4.62909091, 4.67545455,
#        4.72181818, 4.76818182, 4.81454545, 4.86090909, 4.90727273,
#        4.95363636, 5.        ])

# %%
categorias = [
    "4.52-4.56 Baja precisión", 
    "4.57-4.61 Precisión insuficiente", 
    "4.62-4.65 Precisión regular", 
    "4.66-4.69 Precisión aceptable", 
    "4.70-4.74 Precisión buena", 
    "4.75-4.78 Alta precisión", 
    "4.79-4.82 Muy alta precisión", 
    "4.83-4.87 Excelente precisión", 
    "4.88-4.91 Precisión impecable", 
    "4.92-4.95 Casi perfecta precisión", 
    "4.96-5.00 Precisión perfecta"
]

# %%
rio['review_scores_accuracy'] = pd.cut(x = rio['review_scores_accuracy'], bins=intervalos, labels = categorias)
rio['review_scores_accuracy']
# Out:
# 0            4.83-4.87 Excelente precisión
# 1             4.96-5.00 Precisión perfecta
# 2            4.83-4.87 Excelente precisión
# 3        4.92-4.95 Casi perfecta precisión
# 4             4.79-4.82 Muy alta precisión
#                        ...
# 36962         4.79-4.82 Muy alta precisión
# 36963         4.79-4.82 Muy alta precisión
# 36964         4.79-4.82 Muy alta precisión
# 36965         4.79-4.82 Muy alta precisión
# 36966         4.79-4.82 Muy alta precisión
# Name: review_scores_accuracy, Length: 36967, dtype: category
# Categories (11, object): ['4.52-4.56 Baja precisión' < '4.57-4.61 Precisión insuficiente' < '4.62-4.65 Precisión regular' < '4.66-4.69 Precisión aceptable' ... '4.83-4.87 Excelente precisión' < '4.88-4.91 Precisión impecable' < '4.92-4.95 Casi perfecta precisión' < '4.96-5.00 Precisión perfecta']

# %%
tabla2 = freq_tbl(rio['review_scores_accuracy'])
filtro = tabla2[tabla2['frequency'] > 1]
filtro_index = filtro.set_index('review_scores_accuracy')
filtro_index
# Out:
#                                    frequency  percentage  cumulative_perc
# review_scores_accuracy
# 4.96-5.00 Precisión perfecta           12667    0.342657         0.342657
# 4.79-4.82 Muy alta precisión           10552    0.285444         0.628101
# 4.88-4.91 Precisión impecable           4216    0.114048         0.742148
# 4.92-4.95 Casi perfecta precisión       3072    0.083101         0.825250
# 4.83-4.87 Excelente precisión           2227    0.060243         0.885492
# 4.75-4.78 Alta precisión                1119    0.030270         0.915763
# 4.66-4.69 Precisión aceptable            997    0.026970         0.942733
# 4.70-4.74 Precisión buena                753    0.020370         0.963102
# 4.52-4.56 Baja precisión                 665    0.017989         0.981091
# 4.57-4.61 Precisión insuficiente         351    0.009495         0.990586
# 4.62-4.65 Precisión regular              348    0.009414         1.000000

# %%
filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color="purple")
plt.title('Evaluación de precisión del anuncio')
plt.xlabel('Precisión')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
